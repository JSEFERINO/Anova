# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Anova/blob/main/Txt_Anova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# SUBIR A GITHUB DESDE COLAB
# ============================================================

import subprocess
import os

# 1. Instalar git
# !apt-get install git -q

# 2. Configurar git (reemplaza con tus datos)
# !git config --global user.email "juliohur@gmail.com.com"
# !git config --global user.name "Maestro Seferino"

# 3. Copiar archivos
# !cp ../app.py .
# !cp ../requirements.txt .

# 4. Verificar archivos
# !ls -la

# 5. Subir a GitHub
# !git add app.py requirements.txt
# !git commit -m "Añadido statsmodels al requirements.txt"
# !git push origin main

print("✅ Archivos subidos a GitHub")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# cp: cannot stat '../app.py': No such file or directory
# cp: cannot stat '../requirements.txt': No such file or directory
# total 44
# drwxr-xr-x 3 root root  4096 Jul 21 20:00 .
# drwxr-xr-x 1 root root  4096 Jul 21 20:00 ..
# -rw-r--r-- 1 root root 24727 Jul 21 20:00 Anova_app.py
# drwxr-xr-x 8 root root  4096 Jul 21 20:00 .git
# -rw-r--r-- 1 root root    76 Jul 21 20:00 requirements.txt
# fatal: pathspec 'app.py' did not match any files
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ Archivos subidos a GitHub
